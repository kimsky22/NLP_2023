# %% [markdown]
# <a href="https://colab.research.google.com/github/kimsky22/NLP_2023/blob/main/4_3_tryExceptElse_Statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 🔨 try ~ except ~ else/finally
# ---
#
# 1. 프로그램을 작성 후 실행되는 동안 오류가 발생하면 프로그램은 더 이상 진행되지 않는다. 이 상황을 예외 (exeption) 상황이라고 한다.
#
# 2. try: ~ exept:
#   - Exeption 이 있더라도 프로그램 중단 없이 예외에 대하여 적절히 처리하여 프로그램을 진행시킬 수 있도록 하는 구문
#
# 3. try: ~ except: ~ else:
#   - 어떤 로직을 수행했을 때 오류 상황이 아닌 경우에만 어떤 작없을 수행하는 코드를 작성해야 할 때
#   - 예외 Exception 이 발행하면 else 부분은 수행되지 않음
#
# 4. try: ~ except: ~ finally:
#   - 오류 발생과 상관없이 어떤 코드를 무조건 실행 시킬 때

# %%
# 위 #2 의 예시

try:
  print ('How are you?')
  print (param) #param 변수가 정의되지 않았으므로 NameError 예외가 발생. 예외가 발생하면 프로그램은 try 블록을 빠져나와 except 블록으로 이동.

except:
  print ('Exception occurred') #except 블록에서는 "Exception occurred"라는 메시지가 출력된다.
# Out:
# How are you?
# Exception occurred

# %%
try:
  print('how are you?')
  print(param)

except:
  print('exception occurred')
# Out:
# how are you?
# exception occurred

# %%
# 위 #3  (try: ~ exception: ~ else: 에서 else 부분이 실행되지 않은 예시 )

try:
  print ('How are you?')
  print (param) #param 변수를 사용하려고 시도. param 변수가 정의되지 않았으므로 NameError 예외가 발생합니다.

except:
  print ('Exception occurred.') #예외가 발생하면 프로그램은 try 블록을 빠져나와 except 블록으로 이동. except 블록에서는 "Exception occurred."라는 메시지가 출력.


else:
  print ('Exception did not occur.') #else 블록은 실행되지 않는다.
# Out:
# How are you?
# Exception occurred.

# %%
try:
  print('how are you?')
  print(param)

except:
  print('exception occurred.')

else:
  print('exception did not occur.')
# Out:
# how are you?
# exception occurred.

# %%
# 위 #3  (try: ~ exception: ~ else: 에서 except 부분이 실행되지 않은 예시 )

try:
  print ('How are you?')
#  print (param) #해당 코드라인 비활성화시켜 param 변수 사용하여 출력 시도 안함.

except:
  print ('Exception occurred.')

else:
  print ('Exception did not occur.')
# Out:
# How are you?
# Exception did not occur.

# %%
try:
  print('how are you?')

except:
  print('exception occurred.')

else:
  print('exception did not occur.')
# Out:
# how are you?
# exception did not occur.

# %%
# 위 #4  (try: ~ exception: ~ finally: exeption 예외 발생의 유무에 상관없이 무조건 실행되는 finally 부분 )

try:
  print ('How are you?')
#  print (param)

except:
  print ('Exception occurred.')

finally:
  print ('This code should be running.')
# Out:
# How are you?
# This code should be running.

# %%
try:
  print('how are you?')

except:
  print('exception occurred.')

finally:
  print('this code should be running.')
# Out:
# how are you?
# this code should be running.

# %%
treeHit=0
while treeHit < 10:
  treeHit = treeHit + 1
  print("나무를 %번 찍었습니다." % treeHit)
  if treeHit==10:
    print("나무 넘어갑니다.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e3ecfca3e168> in <cell line: 2>()
#       2 while treeHit < 10:
#       3   treeHit = treeHit + 1
# ----> 4   print("나무를 %번 찍었습니다." % treeHit)
#       5   if treeHit==10:
#       6     print("나무 넘어갑니다.")
#
# ValueError: unsupported format character '?' (0xbc88) at index 5

# %%
prompt="""
1.Add
2.Del
3.List
4.Quit

Enter number:"""

# %%
number=0
while number !=4:
  print(prompt)
  number=int(input())

1. Add
2. Del
3. List
4. Quit

Enter number:
# Out:
#   File "<ipython-input-3-d27d909a085a>", line 6
#     1. Add
#        ^
# SyntaxError: invalid syntax

# %%
coffe=10
money=300
while money:
  print("돈을 받았으니 커피를 줍니다.")
  coffee = coffee - 1
  print("남은 커피의 양은 %d개입니다." % coffee)
  if coffee==0:
    print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
    break
# Out:
# 돈을 받았으니 커피를 줍니다.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-69f9003f00e4> in <cell line: 3>()
#       3 while money:
#       4   print("돈을 받았으니 커피를 줍니다.")
# ----> 5   coffee = coffee - 1
#       6   print("남은 커피의 양은 %d개입니다." % coffee)
#       7   if coffee==0:
#
# NameError: name 'coffee' is not defined

# %%
coffee = 10
while True:
  money=int(input("돈을 넣어 주세요:"))
  if money == 300:
    print("커피를 줍니다.")
    coffee = coffee - 1
  elif money > 300:
     print("거스름돈 %d를 주고 커피를 줍니다."%(money-300))
     coffee = coffee - 1
  else:
     print("돈을 다시 돌려주고 커피를 주지 않습니다.")
     print("남은 커피의 양은 %d개입니다." % coffee)
  if coffee==0:
     print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
     break
# Out:
# 돈을 넣어 주세요:1000
# 거스름돈 700를 주고 커피를 줍니다.
# 돈을 넣어 주세요:3000
# 거스름돈 2700를 주고 커피를 줍니다.
# 돈을 넣어 주세요:400
# 거스름돈 100를 주고 커피를 줍니다.
# 돈을 넣어 주세요:100
# 돈을 다시 돌려주고 커피를 주지 않습니다.
# 남은 커피의 양은 7개입니다.

# %%
while True:
    print("Ctrl+C를 눌러야 while 문을 빠져나갈 수 있습니다.")
